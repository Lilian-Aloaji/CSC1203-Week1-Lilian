# %%
# This is a Lap for Week 1

# %%
""" This is a 
    lap for week 1 """
# Out:
# ' This is a \n    lap for week 1 '

# %%
print( "Welcome to Python Programming" )
# Out:
# Welcome to Python Programming

# %%
Name="Lilian Al.Oaji"

# %%
Course="Advance programming methods"

# %%
print(Name)
# Out:
# Lilian Al.Oaji

# %%
print(Course)
# Out:
# Advance programming methods
